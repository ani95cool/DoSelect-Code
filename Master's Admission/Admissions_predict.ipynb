# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
import seaborn as sns

# %%
'''
gre_mean = df['GRE'].mean()
gre_ceil = math.ceil(gre_mean)
print(gre_ceil)
df['GRE'] = df['GRE'].replace(to_replace=np.nan, value=gre_ceil)
df.GRE = df['GRE'].astype('int32')
'''
# Out:
# "\ngre_mean = df['GRE'].mean()\ngre_ceil = math.ceil(gre_mean)\nprint(gre_ceil)\ndf['GRE'] = df['GRE'].replace(to_replace=np.nan, value=gre_ceil)\ndf.GRE = df['GRE'].astype('int32')\n"

# %%
li = []
def format_eng(sc):
    for i in range(len(sc)):
        if(sc[i]>=0 and sc[i]<=4):
            new_score = (0+31)//2
            li.append(new_score)
            #print(new_score)
            #return li
        elif(sc[i]>=4.5 and sc[i]<=5):
            new_score = (32+34)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=5 and sc[i]<=5.5):
            new_score = (35+45)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=5.5 and sc[i]<=6):
            new_score = (46+49)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=6 and sc[i]<=6.5):
            new_score = (60+78)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=6.5 and sc[i]<=7):
            new_score = (79+93)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=7 and sc[i]<=7.5):
            new_score = (94+101)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=7.5 and sc[i]<=8):
            new_score = (102+109)//2
            li.append(new_score)
            #print(new_score)
        elif(sc[i]>=8 and sc[i]<=8.5):
            new_score = (110+114)//2
            #print(new_score)
            li.append(new_score)
        elif(sc[i]>=8.5 and sc[i]<=9):
            new_score = (115+117)//2
            li.append(new_score)
            #print(new_score)
            #return li
        elif(sc[i]>=9 and sc[i]<=10):
            new_score = (118+120)//2
            li.append(new_score)
            #print(new_score)
            #return li
        else:
            li.append(sc[i])
            #return li
            #print(sc)
    df['TOEFL/IELTS'] = li

# %%
#print(list(df['TOEFL/IELTS']))

# %%
marks_list = []
def format_marks(li):
    for marks in range(len(li)):
        if(li[marks] >=0 and li[marks]<=10):
            gpa = li[marks] * 9.5
            marks_list.append(gpa)
        else:
            marks_list.append(li[marks])
    #print(len(marks_list))
    df['MARKS'] = marks_list

# %%
new_df = pd.read_excel('ADMITS.xlsx')
new_df
# Out:
#     University name  GRE  TOEFL/IELTS   MARKS  WORKEX-MONTHS DECISION
# 0      SUNY Buffalo  313          103  68.000             27        A
# 1               NEU  313          103  68.000             27        A
# 2       Polytech NY  313          103  68.000             27        A
# 3               ASU  313          103  68.000             27        A
# 4              NCSU  313          103  68.000             27        R
# 5   Univ of Chicago  313          103  68.000             27        R
# 6               ASU  324          116  87.000             21        A
# 7              NCSU  322          104  80.000             24        A
# 8               ASU  322          104  80.000             24        A
# 9               ASU  310           98  76.000             24        A
# 10  Univ of Florida  315           99  71.000             24        A
# 11              RIT  315           99  71.000             24        A
# 12      Stony Brook  315           99  71.000             24        R
# 13              NEU  315           99  71.000             24        R
# 14             NCSU  315           99  71.000             24        R
# 15    Univ Amherest  315           99  71.000             24        R
# 16              UTA  310           99  68.000             24        A
# 17             NJIT  310           99  68.000             24        A
# 18   CSU Long Beach  310           99  68.000             24        A
# 19              RIT  310           99  68.000             24        A
# 20     SUNY Buffalo  310           99  68.000             24        A
# 21  SUNY Binghamton  310           99  68.000             24        A
# 22              USC  310           99  68.000             24        R
# 23            UPenn  310           99  68.000             24        R
# 24              UCI  310           99  68.000             24        R
# 25              UTD  310           99  68.000             24        R
# 26              UTA  307           80  60.000             72        A
# 27     UMass Lowell  307           80  60.000             72        A
# 28              RIT  307           80  60.000             72        A
# 29             PACE  292           95  68.000             22        A
# 30              UTA  292           95  68.000             22        A
# 31             NYIT  292           95  68.000             22        A
# 32    UMASS Amherst  292           95  68.000             22        R
# 33              UTD  308           95  92.093             23        A
# 34              UTD  312           98  90.345              4        A
# 35              UTD  313          106  87.020              1        A
# 36              UTD  318           98  71.140             28        R
# 37              UTD  316           97  76.500             34        R

# %%
admits_univ = new_df[new_df['DECISION'] == 'A']
rejects_univ = new_df[new_df['DECISION'] == 'R']

# %%
admits_univ
grp = admits_univ.groupby('University name')['DECISION'].count()
series = pd.Series(grp)
count_list = []
name_list = []
for j, k in series.items():
    count_list.append(k)
    name_list.append(j)

# %%
count_admits = pd.DataFrame({'Univ Name': name_list, 'Number of Admits': count_list})
ax = sns.barplot(x="Number of Admits", y="Univ Name", data=count_admits,label="University names vs number of admits")
total = len(count_admits['Univ Name'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
plt.figure(figsize=(500,200))

# %%
rejects_univ
# Out:
#     University name  GRE  TOEFL/IELTS  MARKS  WORKEX-MONTHS DECISION
# 4              NCSU  313          103  68.00             27        R
# 5   Univ of Chicago  313          103  68.00             27        R
# 12      Stony Brook  315           99  71.00             24        R
# 13              NEU  315           99  71.00             24        R
# 14             NCSU  315           99  71.00             24        R
# 15    Univ Amherest  315           99  71.00             24        R
# 22              USC  310           99  68.00             24        R
# 23            UPenn  310           99  68.00             24        R
# 24              UCI  310           99  68.00             24        R
# 25              UTD  310           99  68.00             24        R
# 32    UMASS Amherst  292           95  68.00             22        R
# 36              UTD  318           98  71.14             28        R
# 37              UTD  316           97  76.50             34        R

# %%
rejects_grp = rejects_univ.groupby('University name')['DECISION'].count()
series = pd.Series(rejects_grp)
count_list = []
name_list = []
for j, v in series.items():
    count_list.append(v)
    name_list.append(j)

# %%
count_rejects = pd.DataFrame({'Univ Name': name_list, 'Number of Rejects': count_list})
ax = sns.barplot(x="Number of Rejects", y="Univ Name", data=count_rejects,label="University names vs number of rejects")
total = len(count_rejects['Univ Name'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
plt.figure(figsize=(500,200))

# %%
unique_names = new_df['University name'].unique()

# %%
unique_list = list(unique_names)

# %%
le = preprocessing.LabelEncoder()
univ_names_list = le.fit_transform(new_df['University name'])
univ_names_list
# Out:
# array([10,  3,  7,  0,  2, 20,  0,  2,  0,  0, 21,  8, 11,  3,  2, 19, 17,
#         4,  1,  8, 10,  9, 16, 15, 12, 18, 17, 14,  8,  6, 17,  5, 13, 18,
#        18, 18, 18, 18])

# %%
new_df['Labels'] = univ_names_list
lbelencoded_vals = new_df['Labels']
label_array = np.array(lbelencoded_vals)
train_df = new_df.iloc[:, 1:5]
train_df['Labels'] = new_df.iloc[:, -1]
new_df
# Out:
#     University name  GRE  TOEFL/IELTS   MARKS  WORKEX-MONTHS DECISION  Labels
# 0      SUNY Buffalo  313          103  68.000             27        A      10
# 1               NEU  313          103  68.000             27        A       3
# 2       Polytech NY  313          103  68.000             27        A       7
# 3               ASU  313          103  68.000             27        A       0
# 4              NCSU  313          103  68.000             27        R       2
# 5   Univ of Chicago  313          103  68.000             27        R      20
# 6               ASU  324          116  87.000             21        A       0
# 7              NCSU  322          104  80.000             24        A       2
# 8               ASU  322          104  80.000             24        A       0
# 9               ASU  310           98  76.000             24        A       0
# 10  Univ of Florida  315           99  71.000             24        A      21
# 11              RIT  315           99  71.000             24        A       8
# 12      Stony Brook  315           99  71.000             24        R      11
# 13              NEU  315           99  71.000             24        R       3
# 14             NCSU  315           99  71.000             24        R       2
# 15    Univ Amherest  315           99  71.000             24        R      19
# 16              UTA  310           99  68.000             24        A      17
# 17             NJIT  310           99  68.000             24        A       4
# 18   CSU Long Beach  310           99  68.000             24        A       1
# 19              RIT  310           99  68.000             24        A       8
# 20     SUNY Buffalo  310           99  68.000             24        A      10
# 21  SUNY Binghamton  310           99  68.000             24        A       9
# 22              USC  310           99  68.000             24        R      16
# 23            UPenn  310           99  68.000             24        R      15
# 24              UCI  310           99  68.000             24        R      12
# 25              UTD  310           99  68.000             24        R      18
# 26              UTA  307           80  60.000             72        A      17
# 27     UMass Lowell  307           80  60.000             72        A      14
# 28              RIT  307           80  60.000             72        A       8
# 29             PACE  292           95  68.000             22        A       6
# 30              UTA  292           95  68.000             22        A      17
# 31             NYIT  292           95  68.000             22        A       5
# 32    UMASS Amherst  292           95  68.000             22        R      13
# 33              UTD  308           95  92.093             23        A      18
# 34              UTD  312           98  90.345              4        A      18
# 35              UTD  313          106  87.020              1        A      18
# 36              UTD  318           98  71.140             28        R      18
# 37              UTD  316           97  76.500             34        R      18

# %%
new_df[new_df['University name'] == 'UCI']
# Out:
#    University name  GRE  TOEFL/IELTS  MARKS  WORKEX-MONTHS DECISION  Labels
# 24             UCI  310           99   68.0             24        R      12

# %%
squared_distance = []
sil = []
iterrations = []
for i in range(2,33):
    iterrations.append(i)
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter = 10, n_init=5)
    km = kmeans.fit(new_df.iloc[:, 1:4])
    labels = kmeans.labels_
    squared_distance.append(km.inertia_)
    sil.append(silhouette_score(new_df.iloc[:, 1:4], labels, metric = 'euclidean'))
# Out:
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (14). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (15). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (16). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (17). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (18). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (19). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (21). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (22). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (23). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (24). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (25). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (26). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (27). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (28). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (29). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (30). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (31). Possibly due to duplicate points in X.
#   return_n_iter=True)
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return_n_iter=True)

# %%
plt.plot(iterrations, squared_distance, 'bx-')
plt.xlabel('Value of K')
plt.ylabel('Squared distance')
plt.title('Finding optimal value of K using Elbow Method')
plt.show()

# %%
plt.plot(iterrations, sil, 'bx-')
plt.xlabel('Value of K')
plt.ylabel('Silhouette Value')
plt.title('Finding optimal value of K using Silhouette Value')
plt.show()

# %%
kmeans = KMeans(n_clusters=25, init='k-means++', max_iter = 200, n_init=20, random_state=0)
arr = np.array(new_df['Labels'])
km = kmeans.fit_predict(np.reshape(arr, (-1,1)))
km
# Out:
# C:\Users\Anirudh Deshpande\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: ConvergenceWarning: Number of distinct clusters (22) found smaller than n_clusters (25). Possibly due to duplicate points in X.
#   return_n_iter=True)
# array([ 0, 12, 16,  6,  2, 11,  6,  2,  6,  6,  9,  7, 17, 12,  2,  1, 23,
#        10, 18,  7,  0, 19,  5, 20, 15,  8, 23, 14,  7,  4, 23, 21,  3,  8,
#         8,  8,  8,  8])

# %%
cluster_numbers = []
for clust in range(len(km)):
    cluster_numbers.append(km[clust])

# %%
new_df['Clusters'] = cluster_numbers
new_df[['University name', 'Clusters']]
mydf = new_df[new_df['Clusters'] == 6]
mydf
# Out:
#   University name  GRE  TOEFL/IELTS  MARKS  WORKEX-MONTHS DECISION  Labels  \
# 3             ASU  313          103   68.0             27        A       0
# 6             ASU  324          116   87.0             21        A       0
# 8             ASU  322          104   80.0             24        A       0
# 9             ASU  310           98   76.0             24        A       0
#
#    Clusters
# 3         6
# 6         6
# 8         6
# 9         6

# %%
new_df['Labels'] = train_df['Labels']

# %%
del train_df['Labels']

# %%
KMeans_df = pd.DataFrame()
KMeans_df['Univ_name'] = new_df['University name']
KMeans_df['Clusters'] = new_df['Clusters']
KMeans_df
# Out:
#           Univ_name  Clusters
# 0      SUNY Buffalo         0
# 1               NEU        12
# 2       Polytech NY        16
# 3               ASU         6
# 4              NCSU         2
# 5   Univ of Chicago        11
# 6               ASU         6
# 7              NCSU         2
# 8               ASU         6
# 9               ASU         6
# 10  Univ of Florida         9
# 11              RIT         7
# 12      Stony Brook        17
# 13              NEU        12
# 14             NCSU         2
# 15    Univ Amherest         1
# 16              UTA        23
# 17             NJIT        10
# 18   CSU Long Beach        18
# 19              RIT         7
# 20     SUNY Buffalo         0
# 21  SUNY Binghamton        19
# 22              USC         5
# 23            UPenn        20
# 24              UCI        15
# 25              UTD         8
# 26              UTA        23
# 27     UMass Lowell        14
# 28              RIT         7
# 29             PACE         4
# 30              UTA        23
# 31             NYIT        21
# 32    UMASS Amherst         3
# 33              UTD         8
# 34              UTD         8
# 35              UTD         8
# 36              UTD         8
# 37              UTD         8

# %%
univ_name_unique = KMeans_df['Univ_name'].unique()

# %%
test_df = pd.read_csv('Test_data.csv', names=['University name', 'GRE', 'TOEFL/IELTS', 'MARKS', 'WORKEX-MONTHS'])
test_df
# Out:
#   University name  GRE  TOEFL/IELTS  MARKS  WORKEX-MONTHS
# 0            NCSU  307          100     90             24
# 1            NCSU  315          100     93             36
# 2            NCSU  320           23     12              0

# %%
partial_test_data = test_df.iloc[:, 1:]

# %%
list_test_df = list(test_df['University name'])
print(list_test_df)
# Out:
# ['NCSU', 'NCSU', 'NCSU']

# %%
clust_numbers = []
for i in list_test_df:
    mydf = KMeans_df[KMeans_df['Univ_name'] == i]
    for k in mydf['Clusters'].unique():
        clust_numbers.append(k)

# %%
clust_numbers
test_df['Clusters'] = clust_numbers

# %%
test_df
# Out:
#   University name  GRE  TOEFL/IELTS  MARKS  WORKEX-MONTHS  Clusters
# 0            NCSU  307          100     90             24         2
# 1            NCSU  315          100     93             36         2
# 2            NCSU  320           23     12              0         2

# %%
test_li = []
li = []
dic = {}
target_label_encoding = preprocessing.LabelEncoder()
knn = KNeighborsClassifier(n_neighbors = 1, metric = 'minkowski', p = 2)
for clusters in clust_numbers:
    li.clear()
    mytraindf = new_df[new_df['Clusters'] == clusters]
    #print(mytraindf)
    maximum = max(mytraindf['GRE'])
    max_record = mytraindf[mytraindf['GRE'] == maximum]
    #print(max_record)
    test_record = test_df[test_df['Clusters'] == clusters]
    #print(test_record)
    test_record_section = test_record.iloc[:, 1:5]
    #print(list(mytraindf['DECISION']))
    decs = list(mytraindf['DECISION'])
    #print(decs)
    #print(mytraindf['DECISION'])
    max_record_section = max_record.iloc[:, 1:5]
    train_section = mytraindf.iloc[:, 1:5]
    #print(train_section)
    #print(decs)
    inp = int(input("Press 1 to exit: "))
    if(inp == 1):
        break
    else:
        X_train = train_section.values
        X_test = test_record_section.values
        knn.fit(X_train, decs)
        y_pred = knn.predict(X_test)
        print(y_pred)
        acc = metrics.accuracy_score(decs, y_pred)
        admit_count = 0
        total = 0
        for vals in range(len(y_pred)):
            if(y_pred[vals] == 'A'):
                admit_count += 1
                #print(admit_count)
                total += 1
            else:
                total += 1
                #print(total)
        prob = (admit_count/total) * 100
        print(prob)
        print(acc)
# Out:
# Press 1 to exit: 9
# ['A' 'A' 'R']
# 66.66666666666666
# 0.6666666666666666
# Press 1 to exit: 6
# ['A' 'A' 'R']
# 66.66666666666666
# 0.6666666666666666
# Press 1 to exit: 9
# ['A' 'A' 'R']
# 66.66666666666666
# 0.6666666666666666

# %% [markdown]
# ###
